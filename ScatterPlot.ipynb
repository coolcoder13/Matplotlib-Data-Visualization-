# %%
# Scatter Plot

import numpy as np
import matplotlib.pyplot as plt
import random

x = np.random.rand(100)
y = np.random.randint(1,100,100)

ax = plt.scatter(x,y,s=y,c=x)           # s=size   c=color
